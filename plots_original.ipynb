# %%
import matplotlib.pyplot as plt 
from archivos.carga_datos import *
from gurobipy import GRB, Model, quicksum
from gurobipy import *
import numpy as np

alimentos, cant_por_tipo, total_alimentos = alimentos(tipos)

cant_de_centros = 1
cant_de_bodegas = 1
cant_de_camiones = 15
P_m = 31000

tmax = 10

T = range(1, tmax + 1)    #tiempo

I = range(1, len(cant_por_tipo) + 1) # Tipos de alimentos 1: Hortofrutícola 2:Congelado 3:Refrigerado
A = range(1, cant_por_tipo[0] + 1) # Alimentos de cada tipo
J = range(1, cant_de_centros + 1) # Cantidad de centros de distribución
K = range(1, cant_de_bodegas + 1) # Cantidad de bodegas de almacenamiento
R = range(1, len(rutas) + 1) # 1:Norte, 2:Centro, 3:Sur
P = range(1, len(paises) + 1) # 1:Chile, 2:Argentina
E = range(1, cant_de_camiones + 1)

# Al[a,i,k,t] ExT[a,i,k,t] Tr[a,i,j,k,t,e] Cam[e,a,i,j,k,t]

Tr = np.zeros((cant_por_tipo[0],len(cant_por_tipo),cant_de_centros,cant_de_bodegas,tmax,cant_de_camiones))
Al = np.zeros((cant_por_tipo[0], len(cant_por_tipo),cant_de_bodegas,tmax))
ExT = np.zeros((cant_por_tipo[0], len(cant_por_tipo),cant_de_bodegas,tmax))
# Cam = np.zeros((cant_de_camiones,cant_por_tipo[0],len(cant_por_tipo),cant_de_centros,cant_de_bodegas,tmax))
Cam = np.zeros((cant_de_camiones,len(cant_por_tipo),cant_de_centros,cant_de_bodegas,tmax))

tipos = ["Hortofruticola", "Congelado", "Refrigerado"]
dict_tipos = dict(zip(I, tipos))
dict_alimentos = {}
for i in I:
    dict_alimentos[i] = dict(zip(A,alimentos[dict_tipos[i]]))
peso_promedio = peso_promedio(tipos)
P_ai = {(a,i): float(peso_promedio[dict_tipos[i]][dict_alimentos[i][a]]) for i in I for a in A}

with open("resultados/resultados_Tr_sv_camch.csv", "r") as file:
    datos = file.readlines()
    file.close()
    datos.pop(0)
    for linea in datos:
        data = linea.strip(" \n").split(",") # Tr,a,i,j,k,t,e
        data = [int(datum) for datum in data]
        Tr[data[1]-1,data[2]-1,data[3]-1,data[4]-1,data[5]-1,data[6]-1] = data[0]


with open("resultados/resultados_Cam_sv_camch.csv", "r") as file:
    datos = file.readlines()
    file.close()
    datos.pop(0)
    for linea in datos:
        data = linea.strip(" \n").split(",") # Cam,e,i,j,k,t
        data = [int(datum) for datum in data]
        # Cam[data[1]-1,data[2]-1,data[3]-1,data[4]-1,data[5]-1,data[6]-1] = data[0]
        Cam[data[1]-1,data[2]-1,data[3]-1,data[4]-1,data[5]-1] = data[0]

with open("resultados/resultados_Al_sv_camch.csv", "r") as file:
    datos = file.readlines()
    file.close()
    datos.pop(0)
    for linea in datos:
        data = linea.strip(" \n").split(",") # Al[a,i,k,t]
        data = [int(datum) for datum in data]
        Al[data[1]-1,data[2]-1,data[3]-1,data[4]-1] = data[0]

with open("resultados/resultados_ExT_sv_camch.csv", "r") as file:
    datos = file.readlines()
    file.close()
    datos.pop(0)
    for linea in datos:
        data = linea.strip(" \n").split(",") # ExT[a,i,k,t]
        data = [int(datum) for datum in data]
        ExT[data[1]-1,data[2]-1,data[3]-1,data[4]-1] = data[0]

# %%
Al_sample = np.sum(Al, axis=(0,1))
ExT_sample = np.sum(ExT, axis=0)
Cam_sum_over_time = np.sum(Cam, axis=(0,1,2,3))
print("np shape Al_sample = ", np.shape(Al_sample))

fig, ax = plt.subplots()
input = Cam_sum_over_time
print(np.shape(input)[0])

ax.scatter(T, input) # Cambiar slicing para graficar}
# for y in range(np.shape(ExT_sample)[0]):
#     ax.scatter(T, ExT_sample[y,:], label="ExT") 
ax.grid(True)
fig.suptitle("Cantidad de camiones enviados por semana")
ax.set_xlabel("Semana")
ax.set_ylabel("Cantidad de camiones")
ax.ticklabel_format(useOffset=False)
ax.set_yticks([0,1,2,3,4,5,6,7,8])
ax.set_xticks(T)
# ax.set_xticklabels(T)
# print(f"max input = {int(np.max(input))}")
# ax.set_yticklabels(range(0,int(np.max(input))))
plt.show()
# Out:
# np shape Al_sample =  (1, 10)
# 10

# %%
# printear (quicksum(Al[a,i,k,t]*P_ai[(a,i)] for a in A for i in I) for k for t
pesos_cam_tiempo = np.zeros((len(E),len(T)))
for e in E:
    print(f"\nCamión {e}")
    for t in T:
        # print(f"Tiempo {t}")
        current_peso = 0
        for j in J:
            for k in K:
                for i in I:
                    # print(f"Tr[:,{i},{j},{k},{t},{e}] = {Tr[:,i-1,j-1,k-1,t-1,e-1]}")
                    if Tr[:,i-1,j-1,k-1,t-1,e-1].any() != 0:
                        print(f"El camión {e} lleva productos de tipo {dict_tipos[i]} en el tiempo t = {t}")
                        for a in A:
                            if Tr[a-1,i-1,j-1,k-1,t-1,e-1] != 0:
                                print(f"Se transportaron {Tr[a-1,i-1,j-1,k-1,t-1,e-1]} unidades de {dict_alimentos[i][a]}.")
                                current_peso += Tr[a-1,i-1,j-1,k-1,t-1,e-1]*P_ai[(a,i)]   
        if current_peso != 0:
            print(f"Peso total para camión e = {e} en tiempo t = {t}: {current_peso} kg.")
        pesos_cam_tiempo[e-1,t-1] = current_peso

# print(pesos_cam_tiempo)

fig, ax = plt.subplots()
input = pesos_cam_tiempo
print(np.shape(input)[0])
for ydim in range(np.shape(input)[0]):
    ax.scatter(T, input[ydim,:], label=f"Camión {ydim+1}") # Cambiar slicing para graficar}

ax.legend(loc='upper right', bbox_to_anchor=[1.3, 1])
ax.grid(True)
fig.suptitle("Peso total por camión por semana")
ax.set_xlabel("Semana")
ax.set_ylabel("kg")
ax.set_xticks(T)
ax.ticklabel_format(useOffset=False)
plt.show()
# Out:
# Camión 1
# El camión 1 lleva productos de tipo Hortofruticola en el tiempo t = 1
# Se transportaron 16460.0 unidades de Platano.
# Se transportaron 47070.0 unidades de Manzana.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 1 en tiempo t = 1: 24999.9 kg.
# El camión 1 lleva productos de tipo Hortofruticola en el tiempo t = 7
# Se transportaron 94265.0 unidades de Platano.
# Se transportaron 47070.0 unidades de Manzana.
# Se transportaron 14461.0 unidades de Limon.
# Peso total para camión e = 1 en tiempo t = 7: 24999.85 kg.
# El camión 1 lleva productos de tipo Hortofruticola en el tiempo t = 9
# Se transportaron 101510.0 unidades de Platano.
# Se transportaron 3466.0 unidades de Manzana.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 1 en tiempo t = 9: 25000.000000000004 kg.
# El camión 1 lleva productos de tipo Refrigerado en el tiempo t = 10
# Se transportaron 8659.0 unidades de Jamon de cerdo.
# Se transportaron 2670.0 unidades de Pate.
# Se transportaron 3961.0 unidades de Queso Gouda.
# Se transportaron 829.0 unidades de Quesillo y queso fresco con sal.
# Se transportaron 3316.0 unidades de Margarina.
# Se transportaron 11882.0 unidades de Lechuga.
# Se transportaron 8155.0 unidades de Jugo liquido.
# Peso total para camión e = 1 en tiempo t = 10: 24999.5 kg.
#
# Camión 2
#
# Camión 3
# El camión 3 lleva productos de tipo Hortofruticola en el tiempo t = 2
# Se transportaron 101510.0 unidades de Platano.
# Se transportaron 32747.0 unidades de Manzana.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Peso total para camión e = 3 en tiempo t = 2: 24999.9 kg.
# El camión 3 lleva productos de tipo Hortofruticola en el tiempo t = 5
# Se transportaron 72772.0 unidades de Platano.
# Se transportaron 47070.0 unidades de Manzana.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Peso total para camión e = 3 en tiempo t = 5: 24999.899999999998 kg.
#
# Camión 4
# El camión 4 lleva productos de tipo Hortofruticola en el tiempo t = 10
# Se transportaron 47070.0 unidades de Manzana.
# Se transportaron 3281.0 unidades de Zapallo.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 4 en tiempo t = 10: 24999.300000000003 kg.
#
# Camión 5
#
# Camión 6
# El camión 6 lleva productos de tipo Hortofruticola en el tiempo t = 1
# Se transportaron 85049.0 unidades de Platano.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Peso total para camión e = 6 en tiempo t = 1: 21607.45 kg.
# El camión 6 lleva productos de tipo Hortofruticola en el tiempo t = 8
# Se transportaron 101510.0 unidades de Platano.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 553.0 unidades de Cebolla nueva.
# Peso total para camión e = 6 en tiempo t = 8: 24999.799999999996 kg.
#
# Camión 7
#
# Camión 8
# El camión 8 lleva productos de tipo Hortofruticola en el tiempo t = 4
# Se transportaron 16460.0 unidades de Platano.
# Se transportaron 47069.0 unidades de Manzana.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 41082.0 unidades de Tomate.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 8 en tiempo t = 4: 24999.500000000004 kg.
#
# Camión 9
# El camión 9 lleva productos de tipo Hortofruticola en el tiempo t = 3
# Se transportaron 26101.0 unidades de Platano.
# Se transportaron 47069.0 unidades de Manzana.
# Se transportaron 41082.0 unidades de Tomate.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 9 en tiempo t = 3: 24999.55 kg.
# El camión 9 lleva productos de tipo Hortofruticola en el tiempo t = 4
# Se transportaron 85049.0 unidades de Platano.
# Se transportaron 3392.0 unidades de Zapallo.
# Se transportaron 16119.0 unidades de Cebolla nueva.
# Se transportaron 11190.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Peso total para camión e = 9 en tiempo t = 4: 24999.050000000003 kg.
# El camión 9 lleva productos de tipo Hortofruticola en el tiempo t = 6
# Se transportaron 101509.0 unidades de Platano.
# Se transportaron 32747.0 unidades de Tomate.
# Se transportaron 16119.0 unidades de Cebolla nueva.
# Peso total para camión e = 9 en tiempo t = 6: 24999.55 kg.
# El camión 9 lleva productos de tipo Congelado en el tiempo t = 10
# Se transportaron 4514.0 unidades de Carne molida.
# Se transportaron 2291.0 unidades de Chuleta de cerdo centro o vetada.
# Se transportaron 5251.0 unidades de Choclo congelado.
# Se transportaron 3685.0 unidades de Pulpa de cerdo.
# Se transportaron 4329.0 unidades de Pechuga de pollo.
# Se transportaron 14094.0 unidades de Trutro de pollo.
# Peso total para camión e = 9 en tiempo t = 10: 24999.300000000003 kg.
#
# Camión 10
# El camión 10 lleva productos de tipo Hortofruticola en el tiempo t = 8
# Se transportaron 1092.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 47070.0 unidades de Manzana.
# Se transportaron 2300.0 unidades de Zapallo.
# Se transportaron 15566.0 unidades de Cebolla nueva.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 10 en tiempo t = 8: 24999.500000000004 kg.
#
# Camión 11
# El camión 11 lleva productos de tipo Hortofruticola en el tiempo t = 1
# Se transportaron 1092.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 19402.0 unidades de Zapallo.
# Peso total para camión e = 11 en tiempo t = 1: 20494.0 kg.
# El camión 11 lleva productos de tipo Hortofruticola en el tiempo t = 7
# Se transportaron 7244.0 unidades de Platano.
# Se transportaron 10070.0 unidades de Zapallo.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Peso total para camión e = 11 en tiempo t = 7: 24999.300000000003 kg.
# El camión 11 lleva productos de tipo Hortofruticola en el tiempo t = 10
# Se transportaron 101509.0 unidades de Platano.
# Se transportaron 110.0 unidades de Zapallo.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 41083.0 unidades de Tomate.
# Peso total para camión e = 11 en tiempo t = 10: 24999.049999999996 kg.
#
# Camión 12
# El camión 12 lleva productos de tipo Hortofruticola en el tiempo t = 2
# Se transportaron 18157.0 unidades de Zapallo.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 12 en tiempo t = 2: 24999.100000000002 kg.
# El camión 12 lleva productos de tipo Hortofruticola en el tiempo t = 3
# Se transportaron 16149.0 unidades de Zapallo.
# Se transportaron 16119.0 unidades de Cebolla nueva.
# Se transportaron 11190.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Peso total para camión e = 12 en tiempo t = 3: 24998.7 kg.
# El camión 12 lleva productos de tipo Hortofruticola en el tiempo t = 6
# Se transportaron 47069.0 unidades de Manzana.
# Se transportaron 3392.0 unidades de Zapallo.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 8335.0 unidades de Tomate.
# Se transportaron 11190.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 12 en tiempo t = 6: 24999.000000000004 kg.
# El camión 12 lleva productos de tipo Congelado en el tiempo t = 10
# Se transportaron 276.0 unidades de Asiento.
# Se transportaron 1105.0 unidades de Carne de pavo molida.
# Se transportaron 1300.0 unidades de Chuleta de cerdo centro o vetada.
# Se transportaron 10164.0 unidades de Pollo entero.
# Se transportaron 2119.0 unidades de Salchicha y vienesa de ave.
# Peso total para camión e = 12 en tiempo t = 10: 24998.0 kg.
#
# Camión 13
# El camión 13 lleva productos de tipo Hortofruticola en el tiempo t = 2
# Se transportaron 14322.0 unidades de Manzana.
# Se transportaron 10234.0 unidades de Zapallo.
# Se transportaron 14461.0 unidades de Limon.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Peso total para camión e = 13 en tiempo t = 2: 24999.3 kg.
# El camión 13 lleva productos de tipo Hortofruticola en el tiempo t = 7
# Se transportaron 546.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 17775.0 unidades de Zapallo.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 13 en tiempo t = 7: 24999.2 kg.
#
# Camión 14
# El camión 14 lleva productos de tipo Hortofruticola en el tiempo t = 3
# Se transportaron 1092.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 75408.0 unidades de Platano.
# Se transportaron 11150.0 unidades de Zapallo.
# Se transportaron 14461.0 unidades de Limon.
# Peso total para camión e = 14 en tiempo t = 3: 24999.299999999996 kg.
#
# Camión 15
# El camión 15 lleva productos de tipo Hortofruticola en el tiempo t = 5
# Se transportaron 1092.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 28737.0 unidades de Platano.
# Se transportaron 2300.0 unidades de Zapallo.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 11191.0 unidades de Papa de guarda.
# Se transportaron 11293.0 unidades de Zanahoria.
# Se transportaron 11514.0 unidades de Palta.
# Peso total para camión e = 15 en tiempo t = 5: 24999.450000000004 kg.
# El camión 15 lleva productos de tipo Hortofruticola en el tiempo t = 9
# Se transportaron 43604.0 unidades de Manzana.
# Se transportaron 3392.0 unidades de Zapallo.
# Se transportaron 14462.0 unidades de Limon.
# Se transportaron 41083.0 unidades de Tomate.
# Se transportaron 16120.0 unidades de Cebolla nueva.
# Peso total para camión e = 15 en tiempo t = 9: 24999.600000000002 kg.
# El camión 15 lleva productos de tipo Hortofruticola en el tiempo t = 10
# Se transportaron 546.0 unidades de Aceite vegetal combinado o puro.
# Se transportaron 9687.0 unidades de Zapallo.
# Peso total para camión e = 15 en tiempo t = 10: 10233.0 kg.
# 15

# %%
camiones_array = np.sum(Tr, axis=(0,1,2,3))

fig, ax = plt.subplots()
for camion in E:
    ax.plot(T, camiones_array[:,camion-1], label=f"Camión {camion}")
ax.legend(loc='upper right', bbox_to_anchor=[1.3, 1])
ax.grid(True)
fig.suptitle("Cantidad de alimentos transportada por cada camión.")
ax.set_xlabel("Semana")
ax.set_ylabel("Unidades")
ax.set_xticks(T)
ax.ticklabel_format(useOffset=False)
plt.show()
